# %%
# !git config --global user.name 'Angel Marie Limas'
# !git config --global user.email 'angelmarie.limas@students.isatu.edu.ph'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Limas/IS110_repo_Limas/PythonEnvi_Limas
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Limas/IS110_repo_Limas/PythonEnvi_Limas

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Limas/IS110_repo_Limas/PythonEnvi_Limas

# %%
ls
# Out:
# Chapter2.ipynb  requirements.txt

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: Angel
# Hello Angel

# %%
Hours = float(input("Enter Hours: "))
Rate = float(input("Enter Rate: "))
Pay = float(Hours*Rate)
print("Pay: ", Pay)
# Out:
# Enter Hours: 5
# Enter Rate: 200
# Pay:  1000.0

# %%
width = 17
height = 12.0

print(width // 2, type (width //2))
print(width / 2.0, type (width / 2.0))
print(height / 3, type (width / 3))
print(1+2*5, type (1+2*5))
# Out:
# 8 <class 'int'>
# 8.5 <class 'float'>
# 4.0 <class 'float'>
# 11 <class 'int'>

# %%
number = int(input("Enter a number: "))
square = number*number
print("The square of ", number, "is", square)
# Out:
# Enter a number: 50
# The square of  50 is 2500

# %%
Celsius = float(input("Enter a Celsius: "))
Fahrenheit = (Celsius*9/5)+32
print("Fahrenheit", Fahrenheit)
# Out:
# Enter a Celsius: 40
# Fahrenheit 104.0

# %%
ls
# Out:
# Chapter2.ipynb  requirements.txt
